# %%
import numpy as np

# 수치 미분 함수
def numerical_derivative(f, x):
    delta_x = 1e-4
    grad = np.zeros_like(x)
    
    it = np.nditer(x, flags=['multi_index'], op_flags=['readwrite'])
    
    while not it.finished:
        idx = it.multi_index
        tmp_val = x[idx]
        x[idx] = float(tmp_val) + delta_x
        fx1 = f(x)
        
        x[idx] = tmp_val - delta_x
        fx2 = f(x)
        grad[idx] = (fx1 - fx2) / (2 * delta_x)
        
        x[idx] = tmp_val
        it.iternext()
        
    return grad
        
# calculation function
def predict(x):
    y = np.dot(x, W) + b
    return y

# loss function : mean square error
def loss_func(x, t):
    y = np.dot(x, W) + b
    return ( np.sum((t-y)**2) ) / (len(x))

# data read
loaded_data = np.loadtxt('./regression_testdata_03.csv', delimiter=',', dtype=np.float32)

x_data = loaded_data[ : , 0 : -1]
t_data = loaded_data[ : , [-1]]

print('x shape : ', x_data.shape)
print('t shape : ', t_data.shape)

W = np.random.rand(4,1)
b = np.random.rand(1)

print('W shape : ', W.shape)
print('b shape : ', b.shape)

learning_rate = 1e-2

f = lambda x : loss_func(x_data, t_data)

print('inital error value = ', loss_func(x_data, t_data), ', inital W = ', W, 'b = ', b)

for step in range(8001):
    W -= learning_rate * numerical_derivative(f, W)
    b -= learning_rate * numerical_derivative(f, b)
    
    if( step % 400 == 0):
        print('step = ', step, ', error value = ', loss_func(x_data, t_data), ', W = ', W, ', b = ', b)

perdict(43)
# Out:
# x shape :  (50, 4)
# t shape :  (50, 1)
# W shape :  (4, 1)
# b shape :  (1,)
# inital error value =  58.20892606517884 , inital W =  [[0.60419583]
#  [0.29521235]
#  [0.56611771]
#  [0.74104903]] b =  [0.31629793]
# step =  0 , error value =  29.248784740360655 , W =  [[ 0.45972396]
#  [-0.01212202]
#  [ 0.44909908]
#  [ 0.25193365]] , b =  [0.27907152]
# step =  400 , error value =  5.439761755773146e-06 , W =  [[ 0.99961261]
#  [-1.00032821]
#  [ 0.99995806]
#  [-1.00011795]] , b =  [0.00316522]
# step =  800 , error value =  1.0208706824566682e-09 , W =  [[ 0.99999469]
#  [-1.0000045 ]
#  [ 0.99999943]
#  [-1.00000162]] , b =  [4.33610006e-05]
# step =  1200 , error value =  1.9158503575612841e-13 , W =  [[ 0.99999993]
#  [-1.00000006]
#  [ 0.99999999]
#  [-1.00000002]] , b =  [5.9401132e-07]
# step =  1600 , error value =  3.595443228423899e-17 , W =  [[ 1.]
#  [-1.]
#  [ 1.]
#  [-1.]] , b =  [8.13748409e-09]
# step =  2000 , error value =  6.747500787316386e-21 , W =  [[ 1.]
#  [-1.]
#  [ 1.]
#  [-1.]] , b =  [1.11477188e-10]
# step =  2400 , error value =  1.266768014681969e-24 , W =  [[ 1.]
#  [-1.]
#  [ 1.]
#  [-1.]] , b =  [1.52739757e-12]
# step =  2800 , error value =  2.514379809966945e-28 , W =  [[ 1.]
#  [-1.]
#  [ 1.]
#  [-1.]] , b =  [2.1694411e-14]
# step =  3200 , error value =  5.372264655667141e-30 , W =  [[ 1.]
#  [-1.]
#  [ 1.]
#  [-1.]] , b =  [1.98951311e-15]
# step =  3600 , error value =  5.37265659306249e-30 , W =  [[ 1.]
#  [-1.]
#  [ 1.]
#  [-1.]] , b =  [1.98737386e-15]
# step =  4000 , error value =  5.372895577513847e-30 , W =  [[ 1.]
#  [-1.]
#  [ 1.]
#  [-1.]] , b =  [1.98607626e-15]
# step =  4400 , error value =  5.372786990627683e-30 , W =  [[ 1.]
#  [-1.]
#  [ 1.]
#  [-1.]] , b =  [1.98666521e-15]
# step =  4800 , error value =  5.372686142639588e-30 , W =  [[ 1.]
#  [-1.]
#  [ 1.]
#  [-1.]] , b =  [1.98721314e-15]
# step =  5200 , error value =  5.372930650426605e-30 , W =  [[ 1.]
#  [-1.]
#  [ 1.]
#  [-1.]] , b =  [1.98588626e-15]
# step =  5600 , error value =  5.3728195158068464e-30 , W =  [[ 1.]
#  [-1.]
#  [ 1.]
#  [-1.]] , b =  [1.98648869e-15]
# step =  6000 , error value =  5.37271639155866e-30 , W =  [[ 1.]
#  [-1.]
#  [ 1.]
#  [-1.]] , b =  [1.98704869e-15]
# step =  6400 , error value =  5.372966568801046e-30 , W =  [[ 1.]
#  [-1.]
#  [ 1.]
#  [-1.]] , b =  [1.98569179e-15]
# step =  6800 , error value =  5.372852836377954e-30 , W =  [[ 1.]
#  [-1.]
#  [ 1.]
#  [-1.]] , b =  [1.98630795e-15]
# step =  7200 , error value =  5.372747325620699e-30 , W =  [[ 1.]
#  [-1.]
#  [ 1.]
#  [-1.]] , b =  [1.98688061e-15]
# step =  7600 , error value =  5.372649310546356e-30 , W =  [[ 1.]
#  [-1.]
#  [ 1.]
#  [-1.]] , b =  [1.98741348e-15]
# step =  8000 , error value =  5.372886953621954e-30 , W =  [[ 1.]
#  [-1.]
#  [ 1.]
#  [-1.]] , b =  [1.986123e-15]
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-49df5b951ff4> in <module>
#      61         print('step = ', step, ', error value = ', loss_func(x_data, t_data), ', W = ', W, ', b = ', b)
#      62
# ---> 63 perdict(43)
#
# NameError: name 'perdict' is not defined
